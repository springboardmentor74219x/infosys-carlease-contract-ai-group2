# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.3.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pavan srinivas\desktop\vs code\infosys\infosys-carlease-contract-ai-group2\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\pavan srinivas\desktop\vs code\infosys\infosys-carlease-contract-ai-group2\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------- ----------------------------- 2.9/11.0 MB 15.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.7/11.0 MB 12.4 MB/s eta 0:00:01
#    ------------------ --------------------- 5.0/11.0 MB 11.6 MB/s eta 0:00:01
#    ------------------ --------------------- 5.0/11.0 MB 11.6 MB/s eta 0:00:01
#    -------------------- ------------------- 5.8/11.0 MB 5.9 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.0 MB 5.7 MB/s eta 0:00:01
#    ------------------------------ --------- 8.4/11.0 MB 5.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 5.7 MB/s  0:00:01
# Downloading numpy-2.3.5-cp312-cp312-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.8 MB 6.1 MB/s eta 0:00:02
#    ------ --------------------------------- 2.1/12.8 MB 5.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/12.8 MB 4.0 MB/s eta 0:00:03
#    --------- ------------------------------ 3.1/12.8 MB 3.8 MB/s eta 0:00:03
#    ------------ --------------------------- 3.9/12.8 MB 3.7 MB/s eta 0:00:03
#    --------------- ------------------------ 5.0/12.8 MB 3.9 MB/s eta 0:00:03
#    ------------------ --------------------- 6.0/12.8 MB 4.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.3/12.8 MB 4.4 MB/s eta 0:00:02
#    --------------------------- ------------ 8.7/12.8 MB 4.6 MB/s eta 0:00:01
#    ------------------------------- -------- 10.2/12.8 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.8 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/12.8 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 4.7 MB/s  0:00:02
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
#
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ---------------------------------------- 4/4 [pandas]
#
# Successfully installed numpy-2.3.5 pandas-2.3.3 pytz-2025.2 tzdata-2025.2

# %%
import pandas as pd
df = pd.read_csv('../data/sample_car_contracts.csv')
df.head()
# Out:
#    id customer_name contract_type vehicle_type  monthly_emi  interest_rate  \
# 0   1   Rahul Mehta      Car Loan        Sedan        18500            9.5
# 1   2     Anita Rao     Car Lease          SUV        22000            0.0
# 2   3  James Wilson      Car Loan    Hatchback        14500           11.2
# 3   4    Meena Iyer     Car Lease        Sedan        21000            0.0
# 4   5   Arjun Patel      Car Loan          SUV        27500           10.8
#
#    tenure_months                                     clause_summary risk_flag  \
# 0             48  Prepayment allowed only after 24 months with 5...    medium
# 1             36  Lessee must pay for all maintenance and insurance       low
# 2             60  Late payment fee of 3% per month on outstandin...      high
# 3             24  Excess mileage charge of ₹12 per km over 15,00...    medium
# 4             72  Floating interest rate linked to lender's inte...      high
#
#                     issue_type  \
# 0      High prepayment charges
# 1  Standard maintenance clause
# 2          Aggressive late fee
# 3     High excess mileage rate
# 4   Unclear interest benchmark
#
#                                   recommended_action
# 0  Highlight prepayment penalty to user and sugge...
# 1  No action, just explain maintenance responsibi...
# 2  Flag clause and suggest user request cap on la...
# 3  Warn user about extra mileage charges and reco...
# 4  Explain floating rate risk and suggest asking ...

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\pavan srinivas\desktop\vs code\infosys\infosys-carlease-contract-ai-group2\.venv\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pavan srinivas\desktop\vs code\infosys\infosys-carlease-contract-ai-group2\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\pavan srinivas\desktop\vs code\infosys\infosys-carlease-contract-ai-group2\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pavan srinivas\desktop\vs code\infosys\infosys-carlease-contract-ai-group2\.venv\lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pavan srinivas\desktop\vs code\infosys\infosys-carlease-contract-ai-group2\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\pavan srinivas\desktop\vs code\infosys\infosys-carlease-contract-ai-group2\.venv\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\pavan srinivas\desktop\vs code\infosys\infosys-carlease-contract-ai-group2\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\pavan srinivas\desktop\vs code\infosys\infosys-carlease-contract-ai-group2\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\pavan srinivas\desktop\vs code\infosys\infosys-carlease-contract-ai-group2\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pavan srinivas\desktop\vs code\infosys\infosys-carlease-contract-ai-group2\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\pavan srinivas\desktop\vs code\infosys\infosys-carlease-contract-ai-group2\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
risk_counts = df['risk_flag'].value_counts()
plt.figure(figsize=(8,5))
plt.bar(risk_counts.index.astype(str), risk_counts.values)
plt.xlabel("Risk Category")
plt.ylabel("Number of Customers")
plt.title("Customer Count by Risk Flag")
plt.show()
