# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

df = pd.read_csv('../data/sample_car_contracts1.csv')
df.head()
# Out:
#    id customer_name                  email_id    phone_no  \
# 0   1   Arjun Mehta   arjun.mehta@example.com  9876543210
# 1   2   Pooja Reddy   pooja.reddy@example.com  9123456780
# 2   3  Rahul Sharma  rahul.sharma@example.com  9988776655
# 3   4   Neha Kapoor   neha.kapoor@example.com  9090909090
# 4   5  Vikram Singh  vikram.singh@example.com  9812345678
#
#            contract_type vehicle_type  monthly_emi  interest_rate  \
# 0           New Car Loan        Sedan        13450            8.5
# 1          Used Car Loan    Hatchback         8900           10.2
# 2  Electric Vehicle Loan       EV SUV        15200            7.8
# 3         Refinance Loan        Sedan        11200            9.1
# 4           New Car Loan  Compact SUV        14500            8.2
#
#    tenure_months                                     clause_summary risk_flag  \
# 0             60  Includes prepayment penalty clause; mandatory ...       Low
# ...

# %%
df.shape
# Out:
# (20, 13)

# %%
df.columns
# Out:
# Index(['id', 'customer_name', 'email_id', 'phone_no', 'contract_type',
#        'vehicle_type', 'monthly_emi', 'interest_rate', 'tenure_months',
#        'clause_summary', 'risk_flag', 'issue_type', 'recommended_action'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20 non-null     int64
#  1   customer_name       20 non-null     object
#  2   email_id            20 non-null     object
#  3   phone_no            20 non-null     int64
#  4   contract_type       20 non-null     object
#  5   vehicle_type        20 non-null     object
#  6   monthly_emi         20 non-null     int64
#  7   interest_rate       20 non-null     float64
#  8   tenure_months       20 non-null     int64
#  9   clause_summary      20 non-null     object
#  10  risk_flag           20 non-null     object
#  11  issue_type          13 non-null     object
#  12  recommended_action  20 non-null     object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 2.2+ KB

# %%
df[['id','customer_name','contract_type','loan_amount','risk_level']].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df[['id','customer_name','contract_type','loan_amount','risk_level']].head(10)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
# ...

# %%
df[['id','clause_summary']].head(3)
# Out:
#    id                                     clause_summary
# 0   1  Prepayment allowed only after 24 months with 5...
# 1   2  Lessee must pay for all maintenance and insurance
# 2   3  Late payment fee of 3% per month on outstandin...

# %%
df[['monthly_emi','interest_rate','tenure_months']].describe()
# Out:
#         monthly_emi  interest_rate  tenure_months
# count     12.000000      12.000000       12.00000
# mean   20975.000000       5.233333       47.00000
# std     5257.743208       5.536217       17.50844
# min    13200.000000       0.000000       24.00000
# 25%    18000.000000       0.000000       36.00000
# 50%    20250.000000       4.450000       45.00000
# 75%    24750.000000      10.125000       51.00000
# max    30500.000000      12.500000       84.00000

# %%
# Check missing values
df.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Check missing values
# ----> 2 df.isna().sum()
#
# NameError: name 'df' is not defined

# %%
df.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.isna().sum()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv('../data/sample_car_contracts.csv')
df.head()
# Out:
#    id customer_name contract_type vehicle_type  monthly_emi  interest_rate  \
# 0   1   Rahul Mehta      Car Loan        Sedan        18500            9.5
# 1   2     Anita Rao     Car Lease          SUV        22000            0.0
# 2   3  James Wilson      Car Loan    Hatchback        14500           11.2
# 3   4    Meena Iyer     Car Lease        Sedan        21000            0.0
# 4   5   Arjun Patel      Car Loan          SUV        27500           10.8
#
#    tenure_months                                     clause_summary risk_flag  \
# 0             48  Prepayment allowed only after 24 months with 5...    medium
# 1             36  Lessee must pay for all maintenance and insurance       low
# 2             60  Late payment fee of 3% per month on outstandin...      high
# 3             24  Excess mileage charge of ₹12 per km over 15,00...    medium
# 4             72  Floating interest rate linked to lender's inte...      high
#
#                     issue_type  \
# ...

# %%
df.isna().sum()
# Out:
# id                    0
# customer_name         0
# contract_type         0
# vehicle_type          0
# monthly_emi           0
# interest_rate         0
# tenure_months         0
# clause_summary        0
# risk_flag             0
# issue_type            0
# recommended_action    0
# dtype: int64

# %%
# Unique values for important categorical columns
df['contract_type'].value_counts()
# Out:
# contract_type
# Car Loan     6
# Car Lease    6
# Name: count, dtype: int64

# %%
df['risk_flag'].value_counts()
# Out:
# risk_flag
# high      5
# medium    4
# low       3
# Name: count, dtype: int64

# %%
#Average interest rate per risk level
df.groupby('risk_flag')['interest_rate'].mean()
# Out:
# risk_flag
# high      6.900000
# low       2.966667
# medium    4.850000
# Name: interest_rate, dtype: float64
