# %%
import pandas as pd
import json

# %%
df = pd.read_csv('../data/Milestone2Day1_contract_evaluation_dataset_Anshita-Shrivastava.csv')
df.head()
# Out:
#    contract_id                                      contract_text  \
# 0            1  This agreement includes APR 9.5%, tenure of 36...
# 1            2  The loan has a term of 48 months with a monthl...
# 2            3  APR is fixed at 11.2% with monthly payment $78...
# 3            4  Customer agrees to a 24 month contract with AP...
# 4            5  Monthly installment shall be $510 for a period...
#
#    expected_apr  expected_term expected_payment expected_penalty
# 0           9.5           36.0              450              NaN
# 1           NaN           48.0              620              NaN
# 2          11.2            NaN              780     Late fee $50
# 3           6.8           24.0              NaN              NaN
# 4           NaN           60.0              510              NaN

# %%
expected_output_format = {
    "apr": None,
    "term_months": None,
    "monthly_payment": None,
    "penalty_clause": None
}

# %%
PROMPT = """
You are an information extraction assistant.

Extract ONLY the following fields from the contract text:
- APR
- Term (months)
- Monthly payment
- Penalty clause

Rules:
- Output must be valid JSON only
- If a field is missing, return null
- Do not guess or infer
- Do not add extra keys

Return exactly this JSON structure:
{{
  "apr": null,
  "term_months": null,
  "monthly_payment": null,
  "penalty_clause": null
}}

Contract Text:
\"\"\"{text}\"\"\"
"""

# %%
def call_llm(prompt_text):
    """
    Dummy LLM response for baseline testing.
    """
    return json.dumps({
        "apr": None,
        "term_months": None,
        "monthly_payment": None,
        "penalty_clause": None
    })

# %%
def extract_fields(contract_text):
    prompt_filled = PROMPT.format(text=contract_text)
    llm_response = call_llm(prompt_filled)
    return json.loads(llm_response)

# %%
sample_contracts = df.sample(5, random_state=1)
sample_contracts
# Out:
#     contract_id                                      contract_text  \
# 14           15  Monthly payment $315 with late fee $30 if dela...
# 13           14  This contract has a tenure of 72 months and AP...
# 17           18              APR 5.9% with no penalties mentioned.
# 3             4  Customer agrees to a 24 month contract with AP...
# 21           22  APR 14.6% applies with early termination charg...
#
#     expected_apr  expected_term expected_payment            expected_penalty
# 14           NaN            NaN              315                Late fee $30
# 13          9.75           72.0              NaN                         NaN
# 17          5.90            NaN              NaN                         NaN
# 3           6.80           24.0              NaN                         NaN
# 21         14.60            NaN              NaN  Early termination fee $500

# %%
extracted_rows = []

for _, row in sample_contracts.iterrows():
    extracted = extract_fields(row["contract_text"])

    extracted_rows.append({
        "contract_text": row["contract_text"],

        "llm_apr": extracted["apr"],
        "llm_term": extracted["term_months"],
        "llm_payment": extracted["monthly_payment"],
        "llm_penalty": extracted["penalty_clause"],

        "expected_apr": row["expected_apr"],
        "expected_term": row["expected_term"],
        "expected_payment": row["expected_payment"],
        "expected_penalty": row["expected_penalty"]
    })

comparison_df = pd.DataFrame(extracted_rows)
comparison_df
# Out:
#                                        contract_text llm_apr llm_term  \
# 0  Monthly payment $315 with late fee $30 if dela...    None     None
# 1  This contract has a tenure of 72 months and AP...    None     None
# 2              APR 5.9% with no penalties mentioned.    None     None
# 3  Customer agrees to a 24 month contract with AP...    None     None
# 4  APR 14.6% applies with early termination charg...    None     None
#
#   llm_payment llm_penalty  expected_apr  expected_term expected_payment  \
# 0        None        None           NaN            NaN              315
# 1        None        None          9.75           72.0              NaN
# 2        None        None          5.90            NaN              NaN
# 3        None        None          6.80           24.0              NaN
# 4        None        None         14.60            NaN              NaN
#
#              expected_penalty
# 0                Late fee $30
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4  Early termination fee $500

# %%
def check_match(predicted, actual):
    if pd.isna(predicted) and pd.isna(actual):
        return 1
    if predicted == actual:
        return 1
    return 0

# %%
comparison_df["apr_match"] = comparison_df.apply(
    lambda r: check_match(r["llm_apr"], r["expected_apr"]), axis=1
)

comparison_df["term_match"] = comparison_df.apply(
    lambda r: check_match(r["llm_term"], r["expected_term"]), axis=1
)

comparison_df["payment_match"] = comparison_df.apply(
    lambda r: check_match(r["llm_payment"], r["expected_payment"]), axis=1
)

comparison_df["penalty_match"] = comparison_df.apply(
    lambda r: check_match(r["llm_penalty"], r["expected_penalty"]), axis=1
)

comparison_df
# Out:
#                                        contract_text llm_apr llm_term  \
# 0  Monthly payment $315 with late fee $30 if dela...    None     None
# 1  This contract has a tenure of 72 months and AP...    None     None
# 2              APR 5.9% with no penalties mentioned.    None     None
# 3  Customer agrees to a 24 month contract with AP...    None     None
# 4  APR 14.6% applies with early termination charg...    None     None
#
#   llm_payment llm_penalty  expected_apr  expected_term expected_payment  \
# 0        None        None           NaN            NaN              315
# 1        None        None          9.75           72.0              NaN
# 2        None        None          5.90            NaN              NaN
# 3        None        None          6.80           24.0              NaN
# 4        None        None         14.60            NaN              NaN
#
#              expected_penalty  apr_match  term_match  payment_match  \
# 0                Late fee $30          1           1              0
# 1                         NaN          0           0              1
# 2                         NaN          0           1              1
# 3                         NaN          0           0              1
# 4  Early termination fee $500          0           1              1
#
#    penalty_match
# 0              0
# 1              1
# 2              1
# 3              1
# 4              0
