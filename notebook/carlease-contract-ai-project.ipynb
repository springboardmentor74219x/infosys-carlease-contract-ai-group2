# %%
#import the data
import pandas as pd

# %%
# df = pd.read_csv('../data/sample_car_contract.csv')
# df = pd.read_csv('C:/Users/Admin/Downloads/sample_car_contracts.csv')
df = pd.read_csv('../data/sample_car_contracts.csv')
df.head()
# Out:
#    id customer_name contract_type vehicle_type  monthly_emi  interest_rate  \
# 0   1   Rahul Mehta      Car Loan        Sedan        18500            9.5
# 1   2     Anita Rao     Car Lease          SUV        22000            0.0
# 2   3  James Wilson      Car Loan    Hatchback        14500           11.2
# 3   4    Meena Iyer     Car Lease        Sedan        21000            0.0
# 4   5   Arjun Patel      Car Loan          SUV        27500           10.8
#
#    tenure_months                                     clause_summary risk_flag  \
# 0             48  Prepayment allowed only after 24 months with 5...    medium
# 1             36  Lessee must pay for all maintenance and insurance       low
# 2             60  Late payment fee of 3% per month on outstandin...      high
# 3             24  Excess mileage charge of ₹12 per km over 15,00...    medium
# 4             72  Floating interest rate linked to lender's inte...      high
#
#                     issue_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  12 non-null     int64
#  1   customer_name       12 non-null     object
#  2   contract_type       12 non-null     object
#  3   vehicle_type        12 non-null     object
#  4   monthly_emi         12 non-null     int64
#  5   interest_rate       12 non-null     float64
#  6   tenure_months       12 non-null     int64
#  7   clause_summary      12 non-null     object
#  8   risk_flag           12 non-null     object
#  9   issue_type          12 non-null     object
#  10  recommended_action  12 non-null     object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.2+ KB

# %%
df.describe()
# Out:
#               id   monthly_emi  interest_rate  tenure_months
# count  12.000000     12.000000      12.000000       12.00000
# mean    6.500000  20975.000000       5.233333       47.00000
# std     3.605551   5257.743208       5.536217       17.50844
# min     1.000000  13200.000000       0.000000       24.00000
# 25%     3.750000  18000.000000       0.000000       36.00000
# 50%     6.500000  20250.000000       4.450000       45.00000
# 75%     9.250000  24750.000000      10.125000       51.00000
# max    12.000000  30500.000000      12.500000       84.00000

# %%
print("Contract type counts:")
print(df['contract_type'].value_counts())

print("\nRisk flag counts:")
print(df['risk_flag'].value_counts())

high_risk = df[df['risk_flag'].str.lower() == 'high']
print("\nHigh-risk records:")
high_risk
# Out:
# Contract type counts:
# contract_type
# Car Loan     6
# Car Lease    6
# Name: count, dtype: int64
#
# Risk flag counts:
# risk_flag
# high      5
# medium    4
# low       3
# Name: count, dtype: int64
#
# High-risk records:
#     id customer_name contract_type vehicle_type  monthly_emi  interest_rate  \
# 2    3  James Wilson      Car Loan    Hatchback        14500           11.2
# 4    5   Arjun Patel      Car Loan          SUV        27500           10.8
# 5    6     Sana Khan     Car Lease    Hatchback        16500            0.0
# 8    9     David Roy      Car Loan          SUV        30500           12.5
# 11  12     Imran Ali     Car Lease          SUV        24500            0.0
#
#     tenure_months                                     clause_summary  \
# 2              60  Late payment fee of 3% per month on outstandin...
# 4              72  Floating interest rate linked to lender's inte...
# 5              36     Early termination fee equal to 6 months of EMI
# ...

# %%
hi
