# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/milestone1_humera_khan.csv")
df.head()
# Out:
#    contract_id                                           raw_text    apr  \
# 0            1  This contract between Prime Auto and Emily Sto...  10.49
# 1            2  This contract between ABC Motors and Priya Sha...   3.78
# 2            3  This contract between DriveEasy Finance and Sa...   5.41
# 3            4  This contract between National Motors and Alex...   5.26
# 4            5  This contract between National Motors and John...   5.97
#
#    term_months  monthly_payment              penalty_clause  \
# 0           24              959                         NaN
# 1           24              804  Early termination fee $300
# 2           24              774                Late fee $50
# 3           48             1028                Late fee $25
# 4           36             1180                         NaN
#
#   recommended_action risk_flag
# 0            Approve       Low
# 1            Approve       Low
# 2             Reject      High
# 3            Approve      High
# 4            Approve       Low

# %%
# Ground Truth Simulation

df["expected_apr"] = df["apr"]
df["expected_term"] = df["term_months"]
df["expeted_payment"] = df["monthly_payment"]
df["expected_penalty"] = df["penalty_clause"]

# %%
df.columns
# Out:
# Index(['contract_id', 'raw_text', 'apr', 'term_months', 'monthly_payment',
#        'penalty_clause', 'recommended_action', 'risk_flag', 'expected_apr',
#        'expected_term', 'expeted_payment', 'expected_penalty'],
#       dtype='object')

# %%
df = df.rename(columns={"penalty": "penalty_clause"})

# %%
df.columns
# Out:
# Index(['contract_id', 'raw_text', 'apr', 'term_months', 'monthly_payment',
#        'penalty_clause', 'recommended_action', 'risk_flag', 'expected_apr',
#        'expected_term', 'expeted_payment', 'expected_penalty'],
#       dtype='object')

# %%
df["expected_apr"] = df["apr"]
df["expected_term"] = df["term_months"]
df["expeted_payment"] = df["monthly_payment"]
df["expected_penalty"] = df["penalty_clause"]

# %%
df[["penalty_clause","expected_penalty"]].head()
# Out:
#                penalty_clause            expected_penalty
# 0                         NaN                         NaN
# 1  Early termination fee $300  Early termination fee $300
# 2                Late fee $50                Late fee $50
# 3                Late fee $25                Late fee $25
# 4                         NaN                         NaN

# %%
# if extracted APR exactly matches expected
# APR score 1
# if not score 0

# if extracted term months equals expected
# term months score 1
# else score 0

# if extracted penalty text matches expected
# penalty score 1
# else score 0

df["apr_score"] = (df["apr"] == df["expected_apr"]).astype(int)


df["term_score"] = (df["term_months"] == df["expected_term"]).astype(int)
df["penalty_score"] = (df["penalty_clause"] == df["expected_penalty"]).astype(int)

df["total_score"] = (df["apr_score"] + df["term_score"] + df["payment_score"] + df["penalty_score"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\humer\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'payment_score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 19
#      16 df["term_score"] = (df["term_months"] == df["expected_term"]).astype(int)
#      17 df["penalty_score"] = (df["penalty_clause"] == df["expected_penalty"]).astype(int)
# ---> 19 df["total_score"] = (df["apr_score"] + df["term_score"] + df["payment_score"] + df["penalty_score"])
#
# File c:\Users\humer\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\humer\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'payment_score'

# %%
df["apr_score"] = (df["apr"] == df["expected_apr"]).astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\humer\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'expected_apr'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df["apr_score"] = (df["apr"] == df["expected_apr"]).astype(int)
#
# File c:\Users\humer\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\humer\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'expected_apr'

# %%
df["term_score"] = (df["term_months"] == df["expected_term"]).astype(int)

# %%
df["penalty_score"] = (df["penalty_clause"] == df["expected_penalty"]).astype(int)

# %%
df["total_score"] = (df["apr_score"] + df["term_score"] + df["penalty_score"])

# %%
df["quality_percent"] = (df["total_score"]/3)*100

# %%
df[["apr_score","term_score","penalty_score","total_score","quality_percent"]].head()
# Out:
#    apr_score  term_score  penalty_score  total_score  quality_percent
# 0          1           1              0            2        66.666667
# 1          1           1              1            3       100.000000
# 2          1           1              1            3       100.000000
# 3          1           1              1            3       100.000000
# 4          1           1              0            2        66.666667

# %%
df.to_csv("../data/milestone2_humera_khan.csv",index=False)
