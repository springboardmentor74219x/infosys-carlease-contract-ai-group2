# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\tulas\\OneDrive\\Desktop\\infosys-springboard car-lease project\\infosys-carlease-contract-ai-group2\\notebook'

# %%
os.listdir()
# Out:
# ['car_loan_analysis.ipynb',
#  'contract_analysis.ipynb',
#  'milestone1_tulasi-vasireddy.ipynb']

# %%
import pandas as pd
df=pd.read_csv('../data/batch2_contracts_125rows.csv')
df.head()
# Out:
#    contract_id                                           raw_text    apr  \
# 0            1  This contract between Prime Auto and Emily Sto...  10.49
# 1            2  This contract between ABC Motors and Priya Sha...   3.78
# 2            3  This contract between DriveEasy Finance and Sa...   5.41
# 3            4  This contract between National Motors and Alex...   5.26
# 4            5  This contract between National Motors and John...   5.97
#
#    term_months  monthly_payment              penalty_clause  \
# 0           24              959                         NaN
# 1           24              804  Early termination fee $300
# 2           24              774                Late fee $50
# 3           48             1028                Late fee $25
# 4           36             1180                         NaN
#
#   recommended_action risk_flag
# 0            Approve       Low
# 1            Approve       Low
# 2             Reject      High
# 3            Approve      High
# 4            Approve       Low

# %%
df.info()
df.describe()
df.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   contract_id         125 non-null    int64
#  1   raw_text            125 non-null    object
#  2   apr                 125 non-null    float64
#  3   term_months         125 non-null    int64
#  4   monthly_payment     125 non-null    int64
#  5   penalty_clause      93 non-null     object
#  6   recommended_action  125 non-null    object
#  7   risk_flag           125 non-null    object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 7.9+ KB
#     contract_id                                           raw_text    apr  \
# 91           92  This contract between CarHub Leasing and Alex ...   5.88
# 45           46  This contract between CarHub Leasing and David...   3.13
# 60           61  This contract between Prime Auto and Sara Lope...  10.84
# 20           21  This contract between Prime Auto and John Doe ...   9.99
# 53           54  This contract between Prime Auto and Sara Lope...  13.98
#
#     term_months  monthly_payment              penalty_clause  \
# 91           60              676  Early termination fee $300
# 45           60             1049                         NaN
# 60           48              612                         NaN
# 20           60              219                Late fee $25
# 53           48              512                Late fee $50
#
#    recommended_action risk_flag
# 91             Reject      High
# 45            Approve       Low
# 60             Reject       Low
# 20    Review manually    Medium
# 53            Approve       Low

# %%
def parse_contract(text):
    result = {}

    # Extract APR
    import re
    apr_match = re.search(r'APR (\d+\.?\d*)%', text)
    result['apr_extracted'] = float(apr_match.group(1)) if apr_match else None

    # Extract term
    term_match = re.search(r'(\d+) months', text)
    result['term_extracted'] = int(term_match.group(1)) if term_match else None

    # Extract payment
    payment_match = re.search(r'monthly payment \$?(\d+)', text)
    result['monthly_payment_extracted'] = int(payment_match.group(1)) if payment_match else None

    # Extract penalty
    penalty_match = re.search(r'(Late fee \$\d+|Early termination fee \$\d+|None)', text)
    result['penalty_extracted'] = penalty_match.group(1) if penalty_match else None

    return result

parsed = df['raw_text'].apply(parse_contract)
parsed_df = pd.DataFrame(parsed.tolist())
parsed_df.head()
# Out:
#    apr_extracted  term_extracted  monthly_payment_extracted  \
# 0          10.49              24                        959
# 1           3.78              24                        804
# 2           5.41              24                        774
# 3           5.26              48                       1028
# 4           5.97              36                       1180
#
#             penalty_extracted
# 0                        None
# 1  Early termination fee $300
# 2                Late fee $50
# 3                Late fee $25
# 4                        None

# %%
def risk_rule(row):
    if row['apr'] > 10:
        return "HIGH"
    if row['monthly_payment'] > 900:
        return "MEDIUM"
    return "LOW"

df['rule_based_risk'] = df.apply(risk_rule, axis=1)
df[['raw_text', 'rule_based_risk']].head()
# Out:
#                                             raw_text rule_based_risk
# 0  This contract between Prime Auto and Emily Sto...            HIGH
# 1  This contract between ABC Motors and Priya Sha...             LOW
# 2  This contract between DriveEasy Finance and Sa...             LOW
# 3  This contract between National Motors and Alex...          MEDIUM
# 4  This contract between National Motors and John...          MEDIUM

# %%
import pandas as pd

# %%
final_output
# Out:
# [['contract_id',
#   'raw_text',
#   'apr',
#   'term_months',
#   'monthly_payment',
#   'penalty_clause',
#   'recommended_action',
#   'risk_flag']]

# %%
import os
os.path.exists("../notebook/milestone1_tulasi-vasireddy.csv")
# Out:
# True

# %%
import os
print(os.path.abspath("../notebook/milestone1_tulasi-vasireddy.csv"))
# Out:
# c:\Users\tulas\OneDrive\Desktop\infosys-springboard car-lease project\infosys-carlease-contract-ai-group2\notebook\milestone1_tulasi-vasireddy.csv

# %%
import pandas as pd

df = pd.read_csv("../data/batch2_contracts_125rows.csv")

final_output = df[['contract_id',
                   'raw_text',
                   'apr',
                   'term_months',
                   'monthly_payment',
                   'penalty_clause',
                   'recommended_action',
                   'risk_flag']]

print(final_output.head())
# Out:
#    contract_id                                           raw_text    apr  \
# 0            1  This contract between Prime Auto and Emily Sto...  10.49
# 1            2  This contract between ABC Motors and Priya Sha...   3.78
# 2            3  This contract between DriveEasy Finance and Sa...   5.41
# 3            4  This contract between National Motors and Alex...   5.26
# 4            5  This contract between National Motors and John...   5.97
#
#    term_months  monthly_payment              penalty_clause  \
# 0           24              959                         NaN
# 1           24              804  Early termination fee $300
# 2           24              774                Late fee $50
# 3           48             1028                Late fee $25
# 4           36             1180                         NaN
#
#   recommended_action risk_flag
# 0            Approve       Low
# 1            Approve       Low
# 2             Reject      High
# 3            Approve      High
# 4            Approve       Low

# %%
final_output = df[['contract_id',
                   'raw_text',
                   'apr',
                   'term_months',
                   'monthly_payment',
                   'penalty_clause',
                   'recommended_action',
                   'risk_flag']]

# %%
final_output.to_csv("milestone1_tulasi-vasireddy.csv", index=False)
