# %%
import pandas as pd
import numpy as np

# %%
#Mising Values
print("missing values per column:")
print(df.isnull().sum())
print(f"\ntotal missing values: {df.isnull().sum().sum()}")
print(f"rows with missing values: {df.isnull().any(axis=1).sum()}")
# Out:
# missing values per column:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 #Mising Values
#       2 print("missing values per column:")
# ----> 3 print(df.isnull().sum())
#       4 print(f"\ntotal missing values: {df.isnull().sum().sum()}")
#       5 print(f"rows with missing values: {df.isnull().any(axis=1).sum()}")
#
# NameError: name 'df' is not defined
